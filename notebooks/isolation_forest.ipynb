# %% [markdown]
# # Comparative Analysis
# In this notebook, we compare Isolation Forest with different window size detection techniques.

# %%
import matplotlib

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import numpy as np
import pandas as pd
import daproli as dp

import pandas as pd
pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme()
sns.set_color_codes()

import Orange
import sys
sys.path.append("../")

from tqdm import tqdm

# %% [markdown]
# Let's load the scores from the different methods.

# %%
wsd = ["Human", "FFT", "ACF", "SuSS", "MWF", "Autoperiod", "RobustPeriod"] # 

methods = list()

for algo in wsd:
    candidate_name = f"isolation_forest_{algo}"
    methods.append((algo, f"{candidate_name}.csv"))

for idx, (name, file_name) in enumerate(methods):
    methods[idx] = name, pd.read_csv(f"../experiments/anomaly_detection/isolation_forest/{file_name}")
    
df_scores = pd.DataFrame()

for name, df in methods:
    df_scores["name"] = df.name
    df_scores[name] = df.match
    
df_scores
# Out:
#                                 name  Human    FFT    ACF   SuSS    MWF  \
# 0                   DISTORTED1sddb40  False   True  False   True   True
# 1                   DISTORTED2sddb40  False  False  False  False  False
# 2                   DISTORTED3sddb40  False  False  False  False  False
# 3                    DISTORTEDBIDMC1   True   True   True   True   True
# 4    DISTORTEDCIMIS44AirTemperature1  False  False  False  False  False
# 5    DISTORTEDCIMIS44AirTemperature2  False  False  False  False  False
# 6    DISTORTEDCIMIS44AirTemperature3  False  False  False  False  False
# 7    DISTORTEDCIMIS44AirTemperature4  False  False  False  False  False
# 8    DISTORTEDCIMIS44AirTemperature5  False  False  False  False  False
# 9    DISTORTEDCIMIS44AirTemperature6  False  False  False  False  False
# 10                     DISTORTEDECG1  False   True   True   True   True
# 11                     DISTORTEDECG2  False  False  False  False  False
# 12                     DISTORTEDECG3  False  False  False  False  False
# 13                     DISTORTEDECG3  False  False  False  False  False
# 14                     DISTORTEDECG4  False   True  False  False  False
# 15                     DISTORTEDECG4  False  False  False  False  False
# 16                     DISTORTEDECG4  False  False  False  False  False
# 17                     DISTORTEDECG4  False  False  False  False  False
# 18        DISTORTEDGP711MarkerLFM5z1  False  False  False  False  False
# 19        DISTORTEDGP711MarkerLFM5z2   True   True   True  False   True
# 20        DISTORTEDGP711MarkerLFM5z3  False  False  False   True  False
# 21        DISTORTEDGP711MarkerLFM5z4   True   True   True  False   True
# 22        DISTORTEDGP711MarkerLFM5z5   True   True   True   True   True
# 23       DISTORTEDInternalBleeding10  False  False  False  False  False
# 24       DISTORTEDInternalBleeding14  False  False  False  False  False
# 25       DISTORTEDInternalBleeding15  False   True   True  False  False
# 26       DISTORTEDInternalBleeding16   True  False  False   True  False
# 27       DISTORTEDInternalBleeding17  False  False  False  False  False
# 28       DISTORTEDInternalBleeding18  False  False  False  False  False
# 29       DISTORTEDInternalBleeding19  False  False  False  False  False
# 30       DISTORTEDInternalBleeding20  False   True   True  False   True
# 31        DISTORTEDInternalBleeding4  False   True   True  False  False
# 32        DISTORTEDInternalBleeding5   True   True   True   True   True
# 33        DISTORTEDInternalBleeding6   True   True   True   True   True
# 34        DISTORTEDInternalBleeding8  False  False  False  False  False
# 35        DISTORTEDInternalBleeding9  False  False  False  False  False
# 36       DISTORTEDLab2Cmac011215EPG1   True   True   True   True   True
# 37       DISTORTEDLab2Cmac011215EPG2  False   True  False  False  False
# 38       DISTORTEDLab2Cmac011215EPG3   True   True   True   True   True
# 39       DISTORTEDLab2Cmac011215EPG4  False  False  False  False  False
# 40       DISTORTEDLab2Cmac011215EPG5   True   True   True   True   True
# 41       DISTORTEDLab2Cmac011215EPG6  False  False  False  False  False
# 42   DISTORTEDMesoplodonDensirostris  False  False  False  False  False
# 43             DISTORTEDPowerDemand1  False  False  False  False  False
# 44             DISTORTEDPowerDemand2  False  False  False  False  False
# 45             DISTORTEDPowerDemand3  False  False  False  False  False
# 46             DISTORTEDPowerDemand4  False  False  False  False  False
# 47           DISTORTEDTkeepFifthMARS  False  False  False  False  False
# 48           DISTORTEDTkeepFirstMARS  False  False  False  False  False
# 49           DISTORTEDTkeepForthMARS  False  False  False  False  False
# 50          DISTORTEDTkeepSecondMARS  False  False  False  False  False
# 51           DISTORTEDTkeepThirdMARS  False  False  False  False  False
# 52      DISTORTEDWalkingAceleration1  False  False  False  False  False
# 53      DISTORTEDWalkingAceleration5   True   True   True   True   True
# 54                DISTORTEDapneaecg2   True   True  False   True  False
# 55                DISTORTEDapneaecg3  False  False  False  False  False
# 56                DISTORTEDapneaecg4  False  False  False  False  False
# 57                 DISTORTEDapneaecg  False  False  False  False  False
# 58                    DISTORTEDgait1  False  False  False  False  False
# 59                    DISTORTEDgait2  False  False  False  False  False
# 60                    DISTORTEDgait3  False  False  False  False  False
# 61                DISTORTEDgaitHunt1  False  False  False  False  False
# 62                DISTORTEDgaitHunt2  False  False  False  False  False
# 63                DISTORTEDgaitHunt3  False   True   True  False  False
# 64               DISTORTEDinsectEPG1  False  False  False  False  False
# 65               DISTORTEDinsectEPG2  False  False  False  False  False
# 66               DISTORTEDinsectEPG3  False  False  False  False  False
# 67               DISTORTEDinsectEPG4  False  False  False  False  False
# 68               DISTORTEDinsectEPG5  False   True   True  False   True
# 69           DISTORTEDltstdbs30791AI   True   True   True   True  False
# 70           DISTORTEDltstdbs30791AS   True   True   True   True  False
# 71           DISTORTEDltstdbs30791ES  False  False  False  False  False
# 72                   DISTORTEDpark3m   True   True   True   True  False
# 73             DISTORTEDqtdbSel1005V  False  False  False  False  False
# 74           DISTORTEDqtdbSel100MLII  False  False  False  False  False
# 75            DISTORTEDresperation10  False  False  False  False  False
# 76            DISTORTEDresperation11  False  False  False  False  False
# 77             DISTORTEDresperation1  False  False  False  False  False
# 78             DISTORTEDresperation2  False  False  False  False  False
# 79             DISTORTEDresperation2  False  False  False  False  False
# 80             DISTORTEDresperation3  False  False  False  False  False
# 81             DISTORTEDresperation4  False  False  False  False  False
# 82             DISTORTEDresperation9  False  False  False  False  False
# 83               DISTORTEDs20101mML2   True   True   True   True   True
# 84                  DISTORTEDs20101m  False  False  False  False  False
# 85                   DISTORTEDsddb49  False  False  False  False  False
# 86              DISTORTEDsel840mECG1  False  False  False  False  False
# 87              DISTORTEDsel840mECG2  False  False  False  False  False
# 88                 DISTORTEDtiltAPB1  False  False  False  False  False
# 89                 DISTORTEDtiltAPB2  False  False  False  False  False
# 90                 DISTORTEDtiltAPB3  False  False  False  False  False
# 91                 DISTORTEDtiltAPB4  False  False  False  False  False
# 92                      NOISE1sddb40  False   True  False   True  False
# 93                       NOISEBIDMC1   True   True   True   True  False
# 94       NOISECIMIS44AirTemperature4  False  False  False  False  False
# 95                         NOISEECG4  False   True  False   True  False
# 96            NOISEGP711MarkerLFM5z3  False   True   True  False  False
# 97           NOISEInternalBleeding16  False  False  False  False  False
# 98            NOISEInternalBleeding6   True   True   True   True   True
# 99           NOISELab2Cmac011215EPG1   True   True   True   True   True
# 100          NOISELab2Cmac011215EPG4  False  False   True  False  False
# 101      NOISEMesoplodonDensirostris  False  False  False  False  False
# 102              NOISETkeepThirdMARS   True   True   True   True   True
# 103                   NOISEapneaecg4  False  False  False  False  False
# 104                       NOISEgait3  False  False  False   True  False
# 105                   NOISEgaitHunt2  False  False  False  False  False
# 106                  NOISEinsectEPG3  False  False  False  False  False
# 107                NOISEresperation2  False  False  False  False  False
# 108                          1sddb40  False  False  False   True  False
# 109                          2sddb40  False  False  False  False  False
# 110                          3sddb40  False  False  False  False  False
# 111                           BIDMC1   True  False  False   True   True
# 112           CIMIS44AirTemperature1  False  False  False  False  False
# 113           CIMIS44AirTemperature2  False  False  False  False  False
# 114           CIMIS44AirTemperature3  False  False  False  False  False
# 115           CIMIS44AirTemperature4  False  False  False  False  False
# 116           CIMIS44AirTemperature5  False   True  False  False  False
# 117           CIMIS44AirTemperature6  False  False  False  False   True
# 118                             ECG1   True   True   True   True   True
# 119                             ECG2  False  False  False  False  False
# 120                             ECG3  False  False  False  False  False
# 121                             ECG3  False  False  False  False  False
# 122                             ECG4  False   True   True  False  False
# 123                             ECG4  False  False  False  False  False
# 124                             ECG4  False  False  False  False  False
# 125                             ECG4  False  False  False  False  False
# 126                GP711MarkerLFM5z1  False  False  False  False  False
# 127                GP711MarkerLFM5z2   True   True   True  False   True
# 128                GP711MarkerLFM5z3  False  False  False   True   True
# 129                GP711MarkerLFM5z4   True   True   True   True   True
# 130                GP711MarkerLFM5z5   True  False   True   True  False
# 131               InternalBleeding10  False   True  False  False   True
# 132               InternalBleeding14  False   True   True  False   True
# 133               InternalBleeding15   True   True   True   True   True
# 134               InternalBleeding16  False  False  False   True  False
# 135               InternalBleeding17  False  False  False  False  False
# 136               InternalBleeding18  False  False  False  False  False
# 137               InternalBleeding19  False  False  False   True  False
# 138               InternalBleeding20   True   True   True  False   True
# 139                InternalBleeding4  False   True   True  False  False
# 140                InternalBleeding5   True   True   True  False   True
# 141                InternalBleeding6   True   True   True   True   True
# 142                InternalBleeding8  False  False  False  False  False
# 143                InternalBleeding9  False  False  False  False  False
# 144               Lab2Cmac011215EPG1   True   True   True   True   True
# 145               Lab2Cmac011215EPG2  False  False  False  False  False
# 146               Lab2Cmac011215EPG3   True   True   True   True   True
# 147               Lab2Cmac011215EPG4  False  False  False  False  False
# 148               Lab2Cmac011215EPG5   True   True   True   True   True
# 149               Lab2Cmac011215EPG6  False  False  False  False  False
# 150           MesoplodonDensirostris  False  False  False  False  False
# 151                     PowerDemand1  False  False  False  False  False
# 152                     PowerDemand2  False  False  False  False  False
# 153                     PowerDemand3  False  False  False  False  False
# 154                     PowerDemand4  False  False  False  False  False
# 155                   TkeepFifthMARS  False  False  False  False  False
# 156                   TkeepFirstMARS  False  False  False  False  False
# 157                   TkeepForthMARS  False  False  False  False  False
# 158                  TkeepSecondMARS   True   True   True  False   True
# 159                   TkeepThirdMARS   True   True   True   True   True
# 160              WalkingAceleration1  False  False  False  False  False
# 161              WalkingAceleration5   True   True   True   True   True
# 162                        apneaecg2   True   True  False  False  False
# 163                        apneaecg3  False  False  False  False  False
# 164                        apneaecg4  False  False  False  False  False
# 165                         apneaecg  False  False  False  False  False
# 166                            gait1  False   True  False  False  False
# 167                            gait2  False  False  False  False  False
# 168                            gait3  False  False  False  False  False
# 169                        gaitHunt1  False  False  False  False  False
# 170                        gaitHunt2  False  False  False   True  False
# 171                        gaitHunt3  False  False   True   True   True
# 172                       insectEPG1  False  False  False  False  False
# 173                       insectEPG2  False  False  False   True  False
# 174                       insectEPG3  False  False  False  False  False
# 175                       insectEPG4  False  False  False  False  False
# 176                       insectEPG5  False   True   True   True   True
# 177                   ltstdbs30791AI   True   True  False   True  False
# 178                   ltstdbs30791AS   True   True  False   True  False
# 179                   ltstdbs30791ES  False  False  False  False  False
# 180                           park3m   True  False   True  False   True
# 181                     qtdbSel1005V  False  False  False  False  False
# 182                   qtdbSel100MLII  False  False  False  False  False
# 183                    resperation10  False  False  False  False  False
# 184                    resperation11  False  False  False  False  False
# 185                     resperation1  False  False  False  False  False
# 186                     resperation2  False  False  False  False  False
# 187                     resperation2  False  False  False  False  False
# 188                     resperation3  False  False  False  False  False
# 189                     resperation4  False  False  False  False  False
# 190                     resperation9  False  False  False  False  False
# 191                       s20101mML2   True   True   True   True   True
# 192                          s20101m  False  False  False  False  False
# 193                           sddb49  False  False  False  False  False
# 194                      sel840mECG1  False  False   True  False   True
# 195                      sel840mECG2  False  False  False  False  False
# 196                         tiltAPB1  False   True  False   True  False
# 197                         tiltAPB2  False  False  False  False  False
# 198                         tiltAPB3  False  False  False  False  False
# 199                         tiltAPB4  False  False  False  False  False
# 200                       CHARISfive   True   True   True   True   True
# 201                       CHARISfive  False  False  False  False  False
# 202                       CHARISfive  False  False  False  False  False
# 203                       CHARISfive  False  False  False  False  False
# 204                       CHARISfive  False  False  False  False  False
# 205                        CHARISten  False  False  False  False  False
# 206                        CHARISten  False  False  False  False  False
# 207                        CHARISten  False   True   True   True  False
# 208                         Fantasia  False  False  False  False  False
# 209               Italianpowerdemand  False  False  False  False  False
# 210               Italianpowerdemand  False  False  False  False  False
# 211               Italianpowerdemand  False  False  False  False  False
# 212                 STAFFIIIDatabase  False  False  False  False  False
# 213                 STAFFIIIDatabase  False  False  False  False  False
# 214                 STAFFIIIDatabase  False  False  False  False  False
# 215                 STAFFIIIDatabase  False  False  False   True  False
# 216                 STAFFIIIDatabase  False  False  False  False  False
# 217                 STAFFIIIDatabase  False  False  False  False  False
# 218                 STAFFIIIDatabase  False  False  False  False  False
# 219                 STAFFIIIDatabase  False  False  False  False  False
# 220                 STAFFIIIDatabase  False  False  False  False  False
# 221              mit14046longtermecg  False   True   True   True   True
# 222              mit14046longtermecg  False  False  False  False  False
# 223              mit14046longtermecg  False  False  False  False  False
# 224              mit14046longtermecg  False  False  False  False  False
# 225              mit14046longtermecg   True   True  False  False  False
# 226              mit14134longtermecg  False  False  False  False  False
# 227              mit14134longtermecg  False  False  False  False  False
# 228              mit14134longtermecg  False  False  False  False  False
# 229              mit14134longtermecg  False  False  False  False  False
# 230              mit14134longtermecg  False  False  False  False  False
# 231              mit14134longtermecg  False  False  False  False  False
# 232              mit14157longtermecg  False  False  False  False  False
# 233              mit14157longtermecg  False  False  False  False  False
# 234              mit14157longtermecg  False  False  False  False  False
# 235              mit14157longtermecg  False  False  False  False  False
# 236              mit14157longtermecg  False  False  False  False  False
# 237              mit14157longtermecg  False  False  False  False  False
# 238              taichidbS0715Master  False  False  False  False  False
# 239              taichidbS0715Master  False  False  False  False  False
# 240              taichidbS0715Master  False  False  False  False  False
# 241                  tilt12744mtable  False  False  False  False  False
# 242                  tilt12744mtable  False  False  False  False  False
# 243                   tilt12754table  False  False  False  False  False
# 244                   tilt12754table  False  False  False  False  False
# 245                  tilt12755mtable  False  False  False  False  False
# 246                  tilt12755mtable  False  False  False  False  False
# 247                        weallwalk  False  False  False  False  False
# 248                        weallwalk  False  False   True  False  False
# 249                        weallwalk  False   True   True   True   True
#
#      Autoperiod  RobustPeriod
# 0         False          True
# 1         False         False
# 2         False         False
# 3          True          True
# 4         False         False
# 5         False         False
# 6         False         False
# 7         False         False
# 8         False         False
# 9         False         False
# 10         True          True
# 11        False         False
# 12        False         False
# 13        False         False
# 14         True         False
# 15        False         False
# 16        False         False
# 17        False         False
# 18        False         False
# 19         True         False
# 20        False         False
# 21         True         False
# 22         True         False
# 23        False         False
# 24        False         False
# 25         True         False
# 26        False         False
# 27        False         False
# 28        False         False
# 29        False         False
# 30         True         False
# 31         True         False
# 32         True          True
# 33         True          True
# 34        False         False
# 35        False         False
# 36         True          True
# 37        False          True
# 38         True          True
# 39         True          True
# 40         True          True
# 41        False         False
# 42        False         False
# 43        False         False
# 44        False         False
# 45        False         False
# 46        False         False
# 47        False         False
# 48        False         False
# 49        False         False
# 50        False         False
# 51        False         False
# 52        False         False
# 53         True          True
# 54        False          True
# 55        False         False
# 56        False         False
# 57        False         False
# 58        False         False
# 59        False         False
# 60        False         False
# 61        False         False
# 62        False         False
# 63         True         False
# 64        False         False
# 65        False         False
# 66        False         False
# 67        False         False
# 68        False          True
# 69         True          True
# 70         True          True
# 71        False         False
# 72        False          True
# 73        False         False
# 74        False         False
# 75        False         False
# 76        False         False
# 77        False         False
# 78        False         False
# 79        False         False
# 80        False         False
# 81        False         False
# 82        False         False
# 83         True          True
# 84        False         False
# 85        False         False
# 86         True         False
# 87        False         False
# 88        False          True
# 89        False         False
# 90        False         False
# 91        False         False
# 92         True          True
# 93         True          True
# 94        False         False
# 95        False         False
# 96         True         False
# 97        False         False
# 98         True          True
# 99         True          True
# 100       False          True
# 101       False         False
# 102        True          True
# 103       False         False
# 104       False         False
# 105       False          True
# 106       False         False
# 107       False         False
# 108       False         False
# 109       False         False
# 110       False         False
# 111        True          True
# 112       False         False
# 113       False         False
# 114       False         False
# 115       False         False
# 116       False         False
# 117       False         False
# 118        True          True
# 119       False         False
# 120       False         False
# 121       False         False
# 122        True         False
# 123       False         False
# 124       False         False
# 125       False         False
# 126       False         False
# 127        True         False
# 128        True         False
# 129        True         False
# 130       False         False
# 131       False         False
# 132        True         False
# 133        True          True
# 134       False         False
# 135       False         False
# 136       False         False
# 137       False         False
# 138        True         False
# 139        True         False
# 140        True         False
# 141        True          True
# 142       False         False
# 143       False         False
# 144        True          True
# 145        True          True
# 146        True          True
# 147       False         False
# 148        True          True
# 149       False         False
# 150       False         False
# 151       False         False
# 152       False         False
# 153       False         False
# 154       False         False
# 155       False         False
# 156       False         False
# 157       False         False
# 158        True          True
# 159        True          True
# 160       False         False
# 161        True          True
# 162       False          True
# 163       False         False
# 164       False         False
# 165       False         False
# 166        True         False
# 167       False         False
# 168       False          True
# 169       False         False
# 170       False          True
# 171       False         False
# 172       False         False
# 173       False         False
# 174       False         False
# 175       False         False
# 176        True         False
# 177        True          True
# 178        True          True
# 179       False         False
# 180        True         False
# 181       False         False
# 182       False         False
# 183       False         False
# 184       False         False
# 185       False         False
# 186       False         False
# 187       False         False
# 188       False         False
# 189       False         False
# 190       False         False
# 191        True          True
# 192       False         False
# 193       False         False
# 194       False         False
# 195       False         False
# 196       False          True
# 197       False         False
# 198       False         False
# 199       False         False
# 200        True          True
# 201       False         False
# 202       False         False
# 203       False         False
# 204       False         False
# 205       False         False
# 206       False         False
# 207       False          True
# 208       False         False
# 209       False         False
# 210       False         False
# 211       False         False
# 212       False          True
# 213       False         False
# 214       False         False
# 215       False         False
# 216       False         False
# 217       False         False
# 218       False         False
# 219       False         False
# 220       False         False
# 221        True          True
# 222       False         False
# 223       False         False
# 224       False         False
# 225       False         False
# 226       False         False
# 227       False         False
# 228       False         False
# 229       False         False
# 230       False         False
# 231       False         False
# 232       False         False
# 233       False         False
# 234       False          True
# 235       False         False
# 236       False         False
# 237       False         False
# 238       False         False
# 239       False         False
# 240       False         False
# 241       False         False
# 242       False         False
# 243       False         False
# 244       False         False
# 245       False         False
# 246       False         False
# 247        True          True
# 248       False         False
# 249       False          True

# %% [markdown]
# Let's calculate the mean/std score.

# %%
df_scores.mean(axis=0)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_4201/3278697802.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.mean(axis=0)
# Human           0.168
# FFT             0.244
# ACF             0.212
# SuSS            0.208
# MWF             0.176
# Autoperiod      0.220
# RobustPeriod    0.200
# dtype: float64

# %%
df_scores.std(axis=0)
# Out:
# /var/folders/5_/fv_bzq1n4n76j6l_jqgndj6c0000gn/T/ipykernel_4201/4283968224.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_scores.std(axis=0)
# Human           0.374616
# FFT             0.430354
# ACF             0.409545
# SuSS            0.406691
# MWF             0.381584
# Autoperiod      0.415077
# RobustPeriod    0.400802
# dtype: float64

# %% [markdown]
# Let's compute the wins per method.

# %%
ranks = df_scores.rank(1, method = 'min', ascending=False)
means = np.array(ranks.mean(axis=0))

# %%
for mean, name in zip(means, df_scores.columns[1:]):
    print(f"{name}:wins={ranks[ranks[name] == 1].shape[0]} rank={np.round(mean, 5)}")
# Out:
# Human:wins=204 rank=1.444
# FFT:wins=223 rank=1.188
# ACF:wins=215 rank=1.292
# SuSS:wins=214 rank=1.388
# MWF:wins=206 rank=1.436
# Autoperiod:wins=217 rank=1.276
# RobustPeriod:wins=212 rank=1.424

# %% [markdown]
# Let's plot and output the ranks.

# %%
cd = Orange.evaluation.scoring.compute_CD(means, df_scores.shape[0])
Orange.evaluation.scoring.graph_ranks(means, df_scores.columns[1:], highv=2, cd=cd, width=5, reverse=True, textspace=1, )
plt.title("Isolation Forest", fontsize=16)
plt.show()

# %% [markdown]
# Let's compute wins/losses against Human.

# %%
selection = "Human"

for rival in df_scores.columns[1:]:
    if rival == selection: continue
    
    df_pair = df_scores[[selection, rival]]
    pair_ranks = df_pair.rank(1, method = 'min', ascending=False)
    
    wins = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 2)].shape[0]
    losses = pair_ranks[(pair_ranks[selection] == 2) & (pair_ranks[rival] == 1)].shape[0]
    ties = pair_ranks[(pair_ranks[selection] == 1) & (pair_ranks[rival] == 1)].shape[0]
    
    assert wins + losses + ties == pair_ranks.shape[0]
    
    print(f"{selection} vs {rival}: (wins/ties/losses): {wins}/{ties}/{losses}")
# Out:
# Human vs FFT: (wins/ties/losses): 4/223/23
# Human vs ACF: (wins/ties/losses): 7/225/18
# Human vs SuSS: (wins/ties/losses): 9/222/19
# Human vs MWF: (wins/ties/losses): 11/226/13
# Human vs Autoperiod: (wins/ties/losses): 6/225/19
# Human vs RobustPeriod: (wins/ties/losses): 11/220/19
